# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Define transformations for dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# Load CIFAR-10 dataset from the 'Q1_Data' folder without re-downloading
cifar10_data = datasets.CIFAR10(root='./Q1_Data', train=True, download=False, transform=transform)

# Filter only cats (class 3) and dogs (class 5)
cat_dog_data = [(img, label) for img, label in cifar10_data if label in [3, 5]]

# Create DataLoader for the filtered dataset
train_loader = DataLoader(cat_dog_data, batch_size=64, shuffle=True)

# %%
import os
import torch
import torch.nn as nn
import numpy as np
from torchvision.utils import save_image

# Create the directory for fake images if it doesn't exist
if not os.path.exists('./Fake_Images'):
    os.makedirs('./Fake_Images')

# Generator network
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(100, 256, 4, 1, 0, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )
    
    def forward(self, x):
        return self.main(x)

# Siamese-like Discriminator network
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True)
        )
        self.fc = nn.Sequential(
            nn.Linear(256*4*4*2, 1),  # 2 because we concatenate two images (real + generated)
            nn.Sigmoid()
        )
    
    def forward(self, img_real, img_generated):
        features_real = self.cnn(img_real).view(img_real.size(0), -1)
        features_generated = self.cnn(img_generated).view(img_generated.size(0), -1)
        combined_features = torch.cat((features_real, features_generated), 1)
        similarity_score = self.fc(combined_features)
        
        # Print similarity score for real and fake images
        print(f"Similarity Score (Real): {similarity_score[0].item():.4f} (Fake): {similarity_score[1].item():.4f}")
        
        return similarity_score

# Initialize networks
generator = Generator()
discriminator = Discriminator()

# Set the loss criterion
criterion = nn.BCELoss()

# Optimizers for Generator and Discriminator
optimizer_G = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Define number of epochs
epochs = 50

# Check if CUDA is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the models to the selected device
generator.to(device)
discriminator.to(device)

# Training loop
for epoch in range(epochs):
    for i, (imgs, _) in enumerate(train_loader):
        
        # Ground truths for real and fake
        real_labels = torch.ones(imgs.size(0), 1).to(device)
        fake_labels = torch.zeros(imgs.size(0), 1).to(device)
        
        # Move real images to device
        imgs = imgs.to(device)

        ### Train Discriminator ###
        
        # Generate fake images
        noise = torch.randn(imgs.size(0), 100, 1, 1).to(device)
        fake_imgs = generator(noise)
        
        # Get discriminator predictions on real and fake images
        real_score = discriminator(imgs, imgs)  # Similarity score for real
        fake_score = discriminator(imgs, fake_imgs)  # Similarity score for fake
        
        # Calculate the loss for real and fake
        d_loss_real = criterion(real_score, real_labels)
        d_loss_fake = criterion(fake_score, fake_labels)
        
        # Total discriminator loss
        d_loss = d_loss_real + d_loss_fake
        
        # Backpropagation and optimization for Discriminator
        optimizer_D.zero_grad()
        d_loss.backward()
        optimizer_D.step()

        ### Train Generator ###
        
        # Generate more fake images
        noise = torch.randn(imgs.size(0), 100, 1, 1).to(device)
        fake_imgs = generator(noise)
        
        # Get discriminator's similarity score for fake images
        fake_score = discriminator(imgs, fake_imgs)
        
        # Generator loss (wants to minimize the dissimilarity score)
        g_loss = criterion(fake_score, real_labels)  # Generator wants similarity with real images
        
        # Backpropagation and optimization for Generator
        optimizer_G.zero_grad()
        g_loss.backward()
        optimizer_G.step()

        # Save generated fake images every few epochs
        if (i + 1) % 100 == 0:  # Save every 100 batches
            save_image(fake_imgs.data, f'./Fake_Images/fake_images_epoch_{epoch+1}_batch_{i+1}.png', normalize=True)

    print(f"Epoch [{epoch}/{epochs}] | D Loss: {d_loss.item():.4f} | G Loss: {g_loss.item():.4f}")
# Out:
# Similarity Score (Real): 0.6712 (Fake): 0.4605
# Similarity Score (Real): 0.5528 (Fake): 0.6388
# Similarity Score (Real): 0.3662 (Fake): 0.2200
# Similarity Score (Real): 0.6348 (Fake): 0.3492
# Similarity Score (Real): 0.4255 (Fake): 0.3843
# Similarity Score (Real): 0.3348 (Fake): 0.2929
# Similarity Score (Real): 0.4901 (Fake): 0.6606
# Similarity Score (Real): 0.3695 (Fake): 0.4951
# Similarity Score (Real): 0.1753 (Fake): 0.1859
# Similarity Score (Real): 0.4523 (Fake): 0.5537
# Similarity Score (Real): 0.4228 (Fake): 0.5019
# Similarity Score (Real): 0.2109 (Fake): 0.3261
# Similarity Score (Real): 0.5251 (Fake): 0.4770
# Similarity Score (Real): 0.2906 (Fake): 0.3335
# Similarity Score (Real): 0.2952 (Fake): 0.1849
# Similarity Score (Real): 0.5885 (Fake): 0.4812
# Similarity Score (Real): 0.3511 (Fake): 0.3551
# Similarity Score (Real): 0.2923 (Fake): 0.2174
# Similarity Score (Real): 0.5661 (Fake): 0.5617
# Similarity Score (Real): 0.3109 (Fake): 0.3501
# Similarity Score (Real): 0.1555 (Fake): 0.1666
# Similarity Score (Real): 0.4668 (Fake): 0.5403
# Similarity Score (Real): 0.4476 (Fake): 0.4458
# Similarity Score (Real): 0.1044 (Fake): 0.1399
# Similarity Score (Real): 0.4589 (Fake): 0.4826
# Similarity Score (Real): 0.2585 (Fake): 0.3280
# Similarity Score (Real): 0.0829 (Fake): 0.1113
# Similarity Score (Real): 0.6766 (Fake): 0.7081
# Similarity Score (Real): 0.2444 (Fake): 0.2714
# Similarity Score (Real): 0.0813 (Fake): 0.0797
# Similarity Score (Real): 0.4569 (Fake): 0.6531
# Similarity Score (Real): 0.3220 (Fake): 0.2933
# Similarity Score (Real): 0.1044 (Fake): 0.0506
# Similarity Score (Real): 0.4862 (Fake): 0.6415
# Similarity Score (Real): 0.3424 (Fake): 0.2529
# Similarity Score (Real): 0.0530 (Fake): 0.0624
# Similarity Score (Real): 0.7532 (Fake): 0.8922
# Similarity Score (Real): 0.2835 (Fake): 0.2309
# Similarity Score (Real): 0.0556 (Fake): 0.0433
# Similarity Score (Real): 0.7753 (Fake): 0.6251
# Similarity Score (Real): 0.2727 (Fake): 0.1705
# Similarity Score (Real): 0.0593 (Fake): 0.0411
# Similarity Score (Real): 0.8954 (Fake): 0.8297
# Similarity Score (Real): 0.1759 (Fake): 0.2154
# Similarity Score (Real): 0.0179 (Fake): 0.0189
# Similarity Score (Real): 0.8280 (Fake): 0.7939
# Similarity Score (Real): 0.1257 (Fake): 0.2097
# Similarity Score (Real): 0.0232 (Fake): 0.0293
# Similarity Score (Real): 0.8068 (Fake): 0.7213
# Similarity Score (Real): 0.2445 (Fake): 0.3643
# Similarity Score (Real): 0.0121 (Fake): 0.0194
# Similarity Score (Real): 0.8034 (Fake): 0.8363
# Similarity Score (Real): 0.1267 (Fake): 0.2358
# Similarity Score (Real): 0.0203 (Fake): 0.0174
# Similarity Score (Real): 0.7793 (Fake): 0.8752
# Similarity Score (Real): 0.2657 (Fake): 0.2185
# Similarity Score (Real): 0.0215 (Fake): 0.0165
# Similarity Score (Real): 0.8089 (Fake): 0.5821
# Similarity Score (Real): 0.2834 (Fake): 0.1888
# Similarity Score (Real): 0.0168 (Fake): 0.0055
# Similarity Score (Real): 0.6763 (Fake): 0.7137
# Similarity Score (Real): 0.3994 (Fake): 0.2030
# Similarity Score (Real): 0.0216 (Fake): 0.0156
# Similarity Score (Real): 0.7795 (Fake): 0.6982
# Similarity Score (Real): 0.2021 (Fake): 0.2114
# Similarity Score (Real): 0.0239 (Fake): 0.0214
# Similarity Score (Real): 0.7233 (Fake): 0.8818
# Similarity Score (Real): 0.1542 (Fake): 0.1372
# Similarity Score (Real): 0.0168 (Fake): 0.0159
# Similarity Score (Real): 0.5674 (Fake): 0.7324
# Similarity Score (Real): 0.4566 (Fake): 0.3528
# Similarity Score (Real): 0.0276 (Fake): 0.0228
# Similarity Score (Real): 0.8274 (Fake): 0.7959
# Similarity Score (Real): 0.2534 (Fake): 0.1104
# Similarity Score (Real): 0.0112 (Fake): 0.0079
# Similarity Score (Real): 0.8695 (Fake): 0.9648
# Similarity Score (Real): 0.1811 (Fake): 0.0986
# Similarity Score (Real): 0.0130 (Fake): 0.0048
# Similarity Score (Real): 0.8756 (Fake): 0.9392
# Similarity Score (Real): 0.0690 (Fake): 0.1156
# Similarity Score (Real): 0.0117 (Fake): 0.0090
# Similarity Score (Real): 0.9198 (Fake): 0.9635
# Similarity Score (Real): 0.1388 (Fake): 0.0892
# Similarity Score (Real): 0.0092 (Fake): 0.0079
# Similarity Score (Real): 0.8348 (Fake): 0.9134
# Similarity Score (Real): 0.1250 (Fake): 0.1510
# Similarity Score (Real): 0.0131 (Fake): 0.0128
# Similarity Score (Real): 0.9705 (Fake): 0.9926
# Similarity Score (Real): 0.1470 (Fake): 0.1109
# Similarity Score (Real): 0.0014 (Fake): 0.0010
# Similarity Score (Real): 0.7058 (Fake): 0.7341
# Similarity Score (Real): 0.0934 (Fake): 0.1056
# Similarity Score (Real): 0.0042 (Fake): 0.0132
# Similarity Score (Real): 0.8029 (Fake): 0.8310
# Similarity Score (Real): 0.1226 (Fake): 0.0858
# Similarity Score (Real): 0.0047 (Fake): 0.0066
# Similarity Score (Real): 0.9797 (Fake): 0.8497
# Similarity Score (Real): 0.0593 (Fake): 0.1254
# Similarity Score (Real): 0.0021 (Fake): 0.0050
# Similarity Score (Real): 0.9510 (Fake): 0.8243
# Similarity Score (Real): 0.0853 (Fake): 0.0877
# Similarity Score (Real): 0.0048 (Fake): 0.0068
# Similarity Score (Real): 0.9624 (Fake): 0.9753
# Similarity Score (Real): 0.1417 (Fake): 0.0612
# Similarity Score (Real): 0.0022 (Fake): 0.0030
# Similarity Score (Real): 0.9155 (Fake): 0.9066
# Similarity Score (Real): 0.0899 (Fake): 0.1122
# Similarity Score (Real): 0.0070 (Fake): 0.0077
# Similarity Score (Real): 0.8956 (Fake): 0.8666
# Similarity Score (Real): 0.0756 (Fake): 0.0705
# Similarity Score (Real): 0.0046 (Fake): 0.0030
# Similarity Score (Real): 0.9270 (Fake): 0.8927
# Similarity Score (Real): 0.0511 (Fake): 0.1969
# Similarity Score (Real): 0.0010 (Fake): 0.0052
# Similarity Score (Real): 0.9101 (Fake): 0.9479
# Similarity Score (Real): 0.0612 (Fake): 0.0730
# Similarity Score (Real): 0.0067 (Fake): 0.0022
# Similarity Score (Real): 0.9423 (Fake): 0.9087
# Similarity Score (Real): 0.1396 (Fake): 0.1111
# Similarity Score (Real): 0.0039 (Fake): 0.0048
# Similarity Score (Real): 0.9384 (Fake): 0.9847
# Similarity Score (Real): 0.1201 (Fake): 0.0537
# Similarity Score (Real): 0.0019 (Fake): 0.0008
# Similarity Score (Real): 0.8241 (Fake): 0.9716
# Similarity Score (Real): 0.0835 (Fake): 0.0081
# Similarity Score (Real): 0.0051 (Fake): 0.0011
# Similarity Score (Real): 0.9535 (Fake): 0.9224
# Similarity Score (Real): 0.0728 (Fake): 0.1338
# Similarity Score (Real): 0.0036 (Fake): 0.0038
# Similarity Score (Real): 0.9636 (Fake): 0.9607
# Similarity Score (Real): 0.0835 (Fake): 0.1339
# Similarity Score (Real): 0.0011 (Fake): 0.0035
# Similarity Score (Real): 0.8964 (Fake): 0.9769
# Similarity Score (Real): 0.0724 (Fake): 0.0068
# Similarity Score (Real): 0.0078 (Fake): 0.0009
# Similarity Score (Real): 0.9603 (Fake): 0.9319
# Similarity Score (Real): 0.0868 (Fake): 0.0377
# Similarity Score (Real): 0.0014 (Fake): 0.0055
# Similarity Score (Real): 0.9668 (Fake): 0.9366
# Similarity Score (Real): 0.0585 (Fake): 0.0804
# Similarity Score (Real): 0.0042 (Fake): 0.0033
# Similarity Score (Real): 0.9083 (Fake): 0.7849
# Similarity Score (Real): 0.1148 (Fake): 0.0567
# Similarity Score (Real): 0.0047 (Fake): 0.0026
# Similarity Score (Real): 0.9382 (Fake): 0.9509
# Similarity Score (Real): 0.0653 (Fake): 0.0791
# Similarity Score (Real): 0.0029 (Fake): 0.0038
# Similarity Score (Real): 0.9632 (Fake): 0.9457
# Similarity Score (Real): 0.0391 (Fake): 0.0408
# Similarity Score (Real): 0.0044 (Fake): 0.0034
# Similarity Score (Real): 0.9941 (Fake): 0.9561
# Similarity Score (Real): 0.0126 (Fake): 0.1100
# Similarity Score (Real): 0.0007 (Fake): 0.0074
# Similarity Score (Real): 0.9702 (Fake): 0.9758
# Similarity Score (Real): 0.0773 (Fake): 0.0458
# Similarity Score (Real): 0.0017 (Fake): 0.0025
# Similarity Score (Real): 0.9619 (Fake): 0.9777
# Similarity Score (Real): 0.0353 (Fake): 0.0153
# Similarity Score (Real): 0.0057 (Fake): 0.0045
# Similarity Score (Real): 0.9528 (Fake): 0.8451
# Similarity Score (Real): 0.0713 (Fake): 0.0722
# Similarity Score (Real): 0.0044 (Fake): 0.0031
# Similarity Score (Real): 0.9642 (Fake): 0.9907
# Similarity Score (Real): 0.0303 (Fake): 0.0185
# Similarity Score (Real): 0.0026 (Fake): 0.0014
# Similarity Score (Real): 0.9781 (Fake): 0.9499
# Similarity Score (Real): 0.0340 (Fake): 0.0688
# Similarity Score (Real): 0.0028 (Fake): 0.0032
# Similarity Score (Real): 0.9607 (Fake): 0.9620
# Similarity Score (Real): 0.0814 (Fake): 0.0479
# Similarity Score (Real): 0.0092 (Fake): 0.0056
# Similarity Score (Real): 0.9636 (Fake): 0.9879
# Similarity Score (Real): 0.0431 (Fake): 0.0237
# Similarity Score (Real): 0.0055 (Fake): 0.0028
# Similarity Score (Real): 0.8855 (Fake): 0.9443
# Similarity Score (Real): 0.0683 (Fake): 0.0562
# Similarity Score (Real): 0.0040 (Fake): 0.0013
# Similarity Score (Real): 0.9795 (Fake): 0.9491
# Similarity Score (Real): 0.0115 (Fake): 0.0392
# Similarity Score (Real): 0.0013 (Fake): 0.0056
# Similarity Score (Real): 0.9923 (Fake): 0.9831
# Similarity Score (Real): 0.0075 (Fake): 0.0568
# Similarity Score (Real): 0.0004 (Fake): 0.0019
# Similarity Score (Real): 0.9645 (Fake): 0.9442
# Similarity Score (Real): 0.0472 (Fake): 0.0210
# Similarity Score (Real): 0.0030 (Fake): 0.0030
# Similarity Score (Real): 0.9769 (Fake): 0.9428
# Similarity Score (Real): 0.0477 (Fake): 0.0882
# Similarity Score (Real): 0.0063 (Fake): 0.0046
# Similarity Score (Real): 0.9111 (Fake): 0.9857
# Similarity Score (Real): 0.1937 (Fake): 0.0304
# Similarity Score (Real): 0.0062 (Fake): 0.0019
# Similarity Score (Real): 0.9502 (Fake): 0.8740
# Similarity Score (Real): 0.0116 (Fake): 0.0272
# Similarity Score (Real): 0.0049 (Fake): 0.0249
# Similarity Score (Real): 0.9273 (Fake): 0.9603
# Similarity Score (Real): 0.0457 (Fake): 0.0161
# Similarity Score (Real): 0.0048 (Fake): 0.0038
# Similarity Score (Real): 0.9913 (Fake): 0.9390
# Similarity Score (Real): 0.0286 (Fake): 0.0514
# Similarity Score (Real): 0.0046 (Fake): 0.0029
# Similarity Score (Real): 0.9629 (Fake): 0.9775
# Similarity Score (Real): 0.0884 (Fake): 0.0635
# Similarity Score (Real): 0.0212 (Fake): 0.0020
# Similarity Score (Real): 0.8080 (Fake): 0.9850
# Similarity Score (Real): 0.0632 (Fake): 0.0228
# Similarity Score (Real): 0.0115 (Fake): 0.0035
# Similarity Score (Real): 0.9953 (Fake): 0.9794
# Similarity Score (Real): 0.0144 (Fake): 0.0414
# Similarity Score (Real): 0.0016 (Fake): 0.0021
# Similarity Score (Real): 0.9947 (Fake): 0.9920
# Similarity Score (Real): 0.0069 (Fake): 0.0505
# Similarity Score (Real): 0.0035 (Fake): 0.0048
# Similarity Score (Real): 0.9901 (Fake): 0.9764
# Similarity Score (Real): 0.0184 (Fake): 0.1061
# Similarity Score (Real): 0.0013 (Fake): 0.0042
# Similarity Score (Real): 0.9647 (Fake): 0.9631
# Similarity Score (Real): 0.0264 (Fake): 0.0138
# Similarity Score (Real): 0.0040 (Fake): 0.0037
# Similarity Score (Real): 0.9390 (Fake): 0.9694
# Similarity Score (Real): 0.0804 (Fake): 0.0142
# Similarity Score (Real): 0.0132 (Fake): 0.0015
# Similarity Score (Real): 0.9000 (Fake): 0.9686
# Similarity Score (Real): 0.0160 (Fake): 0.1936
# Similarity Score (Real): 0.0224 (Fake): 0.0158
# Similarity Score (Real): 0.8677 (Fake): 0.9872
# Similarity Score (Real): 0.0448 (Fake): 0.0299
# Similarity Score (Real): 0.0023 (Fake): 0.0033
# Similarity Score (Real): 0.9241 (Fake): 0.8807
# Similarity Score (Real): 0.0278 (Fake): 0.0645
# Similarity Score (Real): 0.0093 (Fake): 0.0129
# Similarity Score (Real): 0.9280 (Fake): 0.9804
# Similarity Score (Real): 0.1456 (Fake): 0.0521
# Similarity Score (Real): 0.0070 (Fake): 0.0045
# Similarity Score (Real): 0.9258 (Fake): 0.9607
# Similarity Score (Real): 0.0663 (Fake): 0.0421
# Similarity Score (Real): 0.0083 (Fake): 0.0041
# Similarity Score (Real): 0.9631 (Fake): 0.9964
# Similarity Score (Real): 0.0619 (Fake): 0.0059
# Similarity Score (Real): 0.0042 (Fake): 0.0002
# Similarity Score (Real): 0.8684 (Fake): 0.9111
# Similarity Score (Real): 0.0574 (Fake): 0.0563
# Similarity Score (Real): 0.0080 (Fake): 0.0122
# Similarity Score (Real): 0.9069 (Fake): 0.9361
# Similarity Score (Real): 0.0366 (Fake): 0.0674
# Similarity Score (Real): 0.0045 (Fake): 0.0036
# Similarity Score (Real): 0.8554 (Fake): 0.9900
# Similarity Score (Real): 0.1782 (Fake): 0.0166
# Similarity Score (Real): 0.0156 (Fake): 0.0049
# Similarity Score (Real): 0.9732 (Fake): 0.9224
# Similarity Score (Real): 0.0213 (Fake): 0.0725
# Similarity Score (Real): 0.0001 (Fake): 0.0045
# Similarity Score (Real): 0.9558 (Fake): 0.8558
# Similarity Score (Real): 0.0102 (Fake): 0.0402
# Similarity Score (Real): 0.0102 (Fake): 0.0024
# Similarity Score (Real): 0.9566 (Fake): 0.9050
# Similarity Score (Real): 0.1584 (Fake): 0.1101
# Similarity Score (Real): 0.0233 (Fake): 0.0007
# Similarity Score (Real): 0.8730 (Fake): 0.9799
# Similarity Score (Real): 0.0026 (Fake): 0.0026
# Similarity Score (Real): 0.0025 (Fake): 0.2130
# Similarity Score (Real): 0.9583 (Fake): 0.9984
# Similarity Score (Real): 0.0598 (Fake): 0.1997
# Similarity Score (Real): 0.0002 (Fake): 0.0023
# Similarity Score (Real): 0.4484 (Fake): 0.2321
# Similarity Score (Real): 0.0127 (Fake): 0.0236
# Similarity Score (Real): 0.1057 (Fake): 0.4736
# Similarity Score (Real): 0.9769 (Fake): 0.9906
# Similarity Score (Real): 0.0099 (Fake): 0.0569
# Similarity Score (Real): 0.0001 (Fake): 0.0016
# Similarity Score (Real): 0.9078 (Fake): 0.6193
# Similarity Score (Real): 0.0604 (Fake): 0.1963
# Similarity Score (Real): 0.0103 (Fake): 0.2897
# Similarity Score (Real): 0.8598 (Fake): 0.9381
# Similarity Score (Real): 0.0010 (Fake): 0.1631
# Similarity Score (Real): 0.0028 (Fake): 0.0023
# Similarity Score (Real): 0.6393 (Fake): 0.5651
# Similarity Score (Real): 0.1460 (Fake): 0.0463
# Similarity Score (Real): 0.0094 (Fake): 0.0255
# Similarity Score (Real): 0.6688 (Fake): 0.7789
# Similarity Score (Real): 0.0760 (Fake): 0.2051
# Similarity Score (Real): 0.0788 (Fake): 0.0088
# Similarity Score (Real): 0.8478 (Fake): 0.7958
# Similarity Score (Real): 0.0424 (Fake): 0.5524
# Similarity Score (Real): 0.0051 (Fake): 0.0416
# Similarity Score (Real): 0.7864 (Fake): 0.9616
# Similarity Score (Real): 0.0218 (Fake): 0.0020
# Similarity Score (Real): 0.0107 (Fake): 0.0030
# Similarity Score (Real): 0.6311 (Fake): 0.7954
# Similarity Score (Real): 0.7703 (Fake): 0.4041
# Similarity Score (Real): 0.0126 (Fake): 0.0203
# Similarity Score (Real): 0.8724 (Fake): 0.7845
# Similarity Score (Real): 0.0072 (Fake): 0.0164
# Similarity Score (Real): 0.0217 (Fake): 0.0066
# Similarity Score (Real): 0.8636 (Fake): 0.7405
# Similarity Score (Real): 0.0112 (Fake): 0.0468
# Similarity Score (Real): 0.0439 (Fake): 0.0139
# Similarity Score (Real): 0.8395 (Fake): 0.9446
# Similarity Score (Real): 0.1942 (Fake): 0.3254
# Similarity Score (Real): 0.0018 (Fake): 0.0073
# Similarity Score (Real): 0.3686 (Fake): 0.4147
# Similarity Score (Real): 0.0349 (Fake): 0.0563
# Similarity Score (Real): 0.0135 (Fake): 0.0071
# Similarity Score (Real): 0.9151 (Fake): 0.8697
# Similarity Score (Real): 0.5543 (Fake): 0.4305
# Similarity Score (Real): 0.0094 (Fake): 0.0066
# Similarity Score (Real): 0.9233 (Fake): 0.7528
# Similarity Score (Real): 0.0176 (Fake): 0.0569
# Similarity Score (Real): 0.0164 (Fake): 0.1227
# Similarity Score (Real): 0.7776 (Fake): 0.8328
# Similarity Score (Real): 0.3668 (Fake): 0.7309
# Similarity Score (Real): 0.0171 (Fake): 0.0315
# Similarity Score (Real): 0.9167 (Fake): 0.8151
# Similarity Score (Real): 0.0986 (Fake): 0.1322
# Similarity Score (Real): 0.0898 (Fake): 0.0036
# Similarity Score (Real): 0.7809 (Fake): 0.8364
# Similarity Score (Real): 0.1348 (Fake): 0.0457
# Similarity Score (Real): 0.0167 (Fake): 0.0115
# Similarity Score (Real): 0.8926 (Fake): 0.9295
# Similarity Score (Real): 0.1212 (Fake): 0.1053
# Similarity Score (Real): 0.0178 (Fake): 0.0238
# Similarity Score (Real): 0.7828 (Fake): 0.9596
# Similarity Score (Real): 0.1352 (Fake): 0.0086
# Similarity Score (Real): 0.0520 (Fake): 0.0034
# Similarity Score (Real): 0.5957 (Fake): 0.9116
# Similarity Score (Real): 0.6462 (Fake): 0.0304
# Similarity Score (Real): 0.0288 (Fake): 0.0160
# Similarity Score (Real): 0.8753 (Fake): 0.9061
# Similarity Score (Real): 0.1310 (Fake): 0.1856
# Similarity Score (Real): 0.0403 (Fake): 0.0234
# Similarity Score (Real): 0.9966 (Fake): 0.9424
# Similarity Score (Real): 0.0103 (Fake): 0.0972
# Similarity Score (Real): 0.0008 (Fake): 0.0477
# Similarity Score (Real): 0.9261 (Fake): 0.7868
# Similarity Score (Real): 0.3039 (Fake): 0.0835
# Similarity Score (Real): 0.0008 (Fake): 0.0327
# Similarity Score (Real): 0.8689 (Fake): 0.8679
# Similarity Score (Real): 0.4512 (Fake): 0.0483
# Similarity Score (Real): 0.0141 (Fake): 0.0085
# Similarity Score (Real): 0.9104 (Fake): 0.7669
# Similarity Score (Real): 0.0097 (Fake): 0.0060
# Similarity Score (Real): 0.0097 (Fake): 0.0059
# Similarity Score (Real): 0.8036 (Fake): 0.8486
# Similarity Score (Real): 0.1170 (Fake): 0.8114
# Similarity Score (Real): 0.0367 (Fake): 0.0711
# Similarity Score (Real): 0.7143 (Fake): 0.7696
# Similarity Score (Real): 0.0612 (Fake): 0.0258
# Similarity Score (Real): 0.0584 (Fake): 0.0096
# Similarity Score (Real): 0.8965 (Fake): 0.9583
# Similarity Score (Real): 0.0935 (Fake): 0.0112
# Similarity Score (Real): 0.0766 (Fake): 0.0238
# Similarity Score (Real): 0.9379 (Fake): 0.7595
# Similarity Score (Real): 0.0451 (Fake): 0.1418
# Similarity Score (Real): 0.0025 (Fake): 0.0061
# Similarity Score (Real): 0.8618 (Fake): 0.9550
# Similarity Score (Real): 0.0310 (Fake): 0.0130
# Similarity Score (Real): 0.0115 (Fake): 0.0036
# Similarity Score (Real): 0.8640 (Fake): 0.9484
# Similarity Score (Real): 0.1162 (Fake): 0.1770
# Similarity Score (Real): 0.0495 (Fake): 0.1280
# Similarity Score (Real): 0.9181 (Fake): 0.8778
# Similarity Score (Real): 0.0660 (Fake): 0.0257
# Similarity Score (Real): 0.0053 (Fake): 0.0107
# Similarity Score (Real): 0.9236 (Fake): 0.9531
# Similarity Score (Real): 0.0442 (Fake): 0.1608
# Similarity Score (Real): 0.0040 (Fake): 0.0078
# Similarity Score (Real): 0.9775 (Fake): 0.8784
# Similarity Score (Real): 0.0187 (Fake): 0.4012
# Similarity Score (Real): 0.0136 (Fake): 0.0155
# Similarity Score (Real): 0.8345 (Fake): 0.8524
# Similarity Score (Real): 0.6155 (Fake): 0.2437
# Similarity Score (Real): 0.0087 (Fake): 0.0158
# Similarity Score (Real): 0.9623 (Fake): 0.8149
# Similarity Score (Real): 0.0448 (Fake): 0.1194
# Similarity Score (Real): 0.0380 (Fake): 0.0207
# Similarity Score (Real): 0.8551 (Fake): 0.7338
# Similarity Score (Real): 0.1096 (Fake): 0.4120
# Similarity Score (Real): 0.0254 (Fake): 0.0165
# Similarity Score (Real): 0.9498 (Fake): 0.9822
# Similarity Score (Real): 0.1153 (Fake): 0.1614
# Similarity Score (Real): 0.0040 (Fake): 0.0077
# Similarity Score (Real): 0.9930 (Fake): 0.9863
# Similarity Score (Real): 0.0117 (Fake): 0.0144
# Similarity Score (Real): 0.0037 (Fake): 0.0055
# Similarity Score (Real): 0.9640 (Fake): 0.9072
# Similarity Score (Real): 0.0153 (Fake): 0.0860
# Similarity Score (Real): 0.0189 (Fake): 0.0044
# Similarity Score (Real): 0.9995 (Fake): 0.9308
# Similarity Score (Real): 0.0010 (Fake): 0.2750
# Similarity Score (Real): 0.0002 (Fake): 0.0181
# Similarity Score (Real): 0.9366 (Fake): 0.9985
# Similarity Score (Real): 0.0268 (Fake): 0.0067
# Similarity Score (Real): 0.0021 (Fake): 0.0006
# Similarity Score (Real): 0.9844 (Fake): 0.6921
# Similarity Score (Real): 0.0133 (Fake): 0.2355
# Similarity Score (Real): 0.0020 (Fake): 0.0802
# Similarity Score (Real): 0.9424 (Fake): 0.7284
# Similarity Score (Real): 0.6241 (Fake): 0.2939
# Similarity Score (Real): 0.0328 (Fake): 0.0103
# Similarity Score (Real): 0.8643 (Fake): 0.8276
# Similarity Score (Real): 0.4191 (Fake): 0.0363
# Similarity Score (Real): 0.0044 (Fake): 0.0053
# Similarity Score (Real): 0.8349 (Fake): 0.4636
# Similarity Score (Real): 0.0538 (Fake): 0.0737
# Similarity Score (Real): 0.1010 (Fake): 0.1880
# Similarity Score (Real): 0.9609 (Fake): 0.8568
# Similarity Score (Real): 0.4094 (Fake): 0.3432
# Similarity Score (Real): 0.0028 (Fake): 0.0466
# Similarity Score (Real): 0.7714 (Fake): 0.5347
# Similarity Score (Real): 0.0176 (Fake): 0.0076
# Similarity Score (Real): 0.0209 (Fake): 0.1661
# Similarity Score (Real): 0.9951 (Fake): 0.9368
# Similarity Score (Real): 0.0084 (Fake): 0.0445
# Similarity Score (Real): 0.0052 (Fake): 0.0008
# Similarity Score (Real): 0.9194 (Fake): 0.9964
# Similarity Score (Real): 0.1689 (Fake): 0.0019
# Similarity Score (Real): 0.1931 (Fake): 0.0004
# Similarity Score (Real): 0.9185 (Fake): 0.9915
# Similarity Score (Real): 0.1883 (Fake): 0.0325
# Similarity Score (Real): 0.0193 (Fake): 0.0047
# Similarity Score (Real): 0.9184 (Fake): 0.7499
# Similarity Score (Real): 0.1904 (Fake): 0.0593
# Similarity Score (Real): 0.1005 (Fake): 0.0169
# Similarity Score (Real): 0.9181 (Fake): 0.7818
# Similarity Score (Real): 0.0884 (Fake): 0.2104
# Similarity Score (Real): 0.0476 (Fake): 0.0662
# Similarity Score (Real): 0.7548 (Fake): 0.9157
# Similarity Score (Real): 0.2354 (Fake): 0.1015
# Similarity Score (Real): 0.0519 (Fake): 0.0202
# Similarity Score (Real): 0.9688 (Fake): 0.8688
# Similarity Score (Real): 0.0100 (Fake): 0.0085
# Similarity Score (Real): 0.0109 (Fake): 0.0075
# Similarity Score (Real): 0.9758 (Fake): 0.9015
# Similarity Score (Real): 0.1355 (Fake): 0.2655
# Similarity Score (Real): 0.0255 (Fake): 0.0089
# Similarity Score (Real): 0.8997 (Fake): 0.9646
# Similarity Score (Real): 0.0332 (Fake): 0.0526
# Similarity Score (Real): 0.0241 (Fake): 0.0039
# Similarity Score (Real): 0.7112 (Fake): 0.7370
# Similarity Score (Real): 0.1064 (Fake): 0.4710
# Similarity Score (Real): 0.0583 (Fake): 0.0385
# Similarity Score (Real): 0.9372 (Fake): 0.9885
# Similarity Score (Real): 0.0525 (Fake): 0.0114
# Similarity Score (Real): 0.0076 (Fake): 0.0029
# Similarity Score (Real): 0.9002 (Fake): 0.9373
# Similarity Score (Real): 0.0621 (Fake): 0.1279
# Similarity Score (Real): 0.0052 (Fake): 0.0099
# Similarity Score (Real): 0.9126 (Fake): 0.7601
# Similarity Score (Real): 0.0088 (Fake): 0.2792
# Similarity Score (Real): 0.0177 (Fake): 0.0151
# Similarity Score (Real): 0.9462 (Fake): 0.8387
# Similarity Score (Real): 0.0997 (Fake): 0.1622
# Similarity Score (Real): 0.0029 (Fake): 0.0660
# Similarity Score (Real): 0.9882 (Fake): 0.9648
# Similarity Score (Real): 0.0145 (Fake): 0.0550
# Similarity Score (Real): 0.0085 (Fake): 0.0154
# Similarity Score (Real): 0.8988 (Fake): 0.9074
# Similarity Score (Real): 0.1249 (Fake): 0.0148
# Similarity Score (Real): 0.0342 (Fake): 0.0091
# Similarity Score (Real): 0.7693 (Fake): 0.9849
# Similarity Score (Real): 0.1768 (Fake): 0.0302
# Similarity Score (Real): 0.0123 (Fake): 0.0024
# Similarity Score (Real): 0.7963 (Fake): 0.8845
# Similarity Score (Real): 0.0581 (Fake): 0.1229
# Similarity Score (Real): 0.0295 (Fake): 0.0108
# Similarity Score (Real): 0.9519 (Fake): 0.9512
# Similarity Score (Real): 0.0367 (Fake): 0.0180
# Similarity Score (Real): 0.0069 (Fake): 0.0037
# Similarity Score (Real): 0.8798 (Fake): 0.9337
# Similarity Score (Real): 0.0918 (Fake): 0.1695
# Similarity Score (Real): 0.0053 (Fake): 0.0034
# Epoch [0/50] | D Loss: 0.3038 | G Loss: 4.8469
# Similarity Score (Real): 0.9641 (Fake): 0.9935
# Similarity Score (Real): 0.0408 (Fake): 0.0259
# Similarity Score (Real): 0.0143 (Fake): 0.0035
# Similarity Score (Real): 0.9591 (Fake): 0.9223
# Similarity Score (Real): 0.0193 (Fake): 0.0126
# Similarity Score (Real): 0.0014 (Fake): 0.0043
# Similarity Score (Real): 0.9324 (Fake): 0.9751
# Similarity Score (Real): 0.0722 (Fake): 0.0401
# Similarity Score (Real): 0.0064 (Fake): 0.0035
# Similarity Score (Real): 0.9696 (Fake): 0.9422
# Similarity Score (Real): 0.0458 (Fake): 0.0713
# Similarity Score (Real): 0.0079 (Fake): 0.0081
# Similarity Score (Real): 0.9857 (Fake): 0.9558
# Similarity Score (Real): 0.0114 (Fake): 0.0779
# Similarity Score (Real): 0.0009 (Fake): 0.0086
# Similarity Score (Real): 0.9706 (Fake): 0.9920
# Similarity Score (Real): 0.0110 (Fake): 0.0028
# Similarity Score (Real): 0.0055 (Fake): 0.0002
# Similarity Score (Real): 0.9229 (Fake): 0.9203
# Similarity Score (Real): 0.0441 (Fake): 0.0378
# Similarity Score (Real): 0.0056 (Fake): 0.0163
# Similarity Score (Real): 0.9794 (Fake): 0.9994
# Similarity Score (Real): 0.0135 (Fake): 0.0203
# Similarity Score (Real): 0.0029 (Fake): 0.0010
# Similarity Score (Real): 0.9454 (Fake): 0.9943
# Similarity Score (Real): 0.0267 (Fake): 0.0319
# Similarity Score (Real): 0.0131 (Fake): 0.0016
# Similarity Score (Real): 0.9371 (Fake): 0.9721
# Similarity Score (Real): 0.1562 (Fake): 0.0643
# Similarity Score (Real): 0.0040 (Fake): 0.0046
# Similarity Score (Real): 0.9615 (Fake): 0.9620
# Similarity Score (Real): 0.1680 (Fake): 0.0042
# Similarity Score (Real): 0.0004 (Fake): 0.0018
# Similarity Score (Real): 0.9017 (Fake): 0.9490
# Similarity Score (Real): 0.0130 (Fake): 0.0348
# Similarity Score (Real): 0.0104 (Fake): 0.0087
# Similarity Score (Real): 0.9403 (Fake): 0.9704
# Similarity Score (Real): 0.0910 (Fake): 0.0674
# Similarity Score (Real): 0.0210 (Fake): 0.0022
# Similarity Score (Real): 0.8549 (Fake): 0.8970
# Similarity Score (Real): 0.0135 (Fake): 0.0203
# Similarity Score (Real): 0.0045 (Fake): 0.0042
# Similarity Score (Real): 0.8504 (Fake): 0.8380
# Similarity Score (Real): 0.0995 (Fake): 0.0815
# Similarity Score (Real): 0.0047 (Fake): 0.0116
# Similarity Score (Real): 0.8860 (Fake): 0.9815
# Similarity Score (Real): 0.0620 (Fake): 0.0902
# Similarity Score (Real): 0.0055 (Fake): 0.0033
# Similarity Score (Real): 0.9941 (Fake): 0.9719
# Similarity Score (Real): 0.0061 (Fake): 0.0256
# Similarity Score (Real): 0.0003 (Fake): 0.0064
# Similarity Score (Real): 0.9566 (Fake): 0.9352
# Similarity Score (Real): 0.0085 (Fake): 0.0902
# Similarity Score (Real): 0.0013 (Fake): 0.0105
# Similarity Score (Real): 0.8964 (Fake): 0.9452
# Similarity Score (Real): 0.1553 (Fake): 0.0524
# Similarity Score (Real): 0.0048 (Fake): 0.0005
# Similarity Score (Real): 0.9315 (Fake): 0.5567
# Similarity Score (Real): 0.0443 (Fake): 0.5503
# Similarity Score (Real): 0.0019 (Fake): 0.2383
# Similarity Score (Real): 0.8889 (Fake): 0.9222
# Similarity Score (Real): 0.0228 (Fake): 0.0178
# Similarity Score (Real): 0.0044 (Fake): 0.0040
# Similarity Score (Real): 0.1707 (Fake): 0.9791
# Similarity Score (Real): 0.4403 (Fake): 0.0127
# Similarity Score (Real): 0.0121 (Fake): 0.0013
# Similarity Score (Real): 0.8850 (Fake): 0.9314
# Similarity Score (Real): 0.0588 (Fake): 0.0402
# Similarity Score (Real): 0.0010 (Fake): 0.0045
# Similarity Score (Real): 0.9367 (Fake): 0.9215
# Similarity Score (Real): 0.0250 (Fake): 0.2755
# Similarity Score (Real): 0.0041 (Fake): 0.0051
# Similarity Score (Real): 0.7868 (Fake): 0.7785
# Similarity Score (Real): 0.0905 (Fake): 0.0337
# Similarity Score (Real): 0.0071 (Fake): 0.0106
# Similarity Score (Real): 0.9308 (Fake): 0.9647
# Similarity Score (Real): 0.1254 (Fake): 0.1848
# Similarity Score (Real): 0.0040 (Fake): 0.0034
# Similarity Score (Real): 0.8678 (Fake): 0.9431
# Similarity Score (Real): 0.0607 (Fake): 0.0273
# Similarity Score (Real): 0.0014 (Fake): 0.0003
# Similarity Score (Real): 0.8605 (Fake): 0.4286
# Similarity Score (Real): 0.1092 (Fake): 0.3109
# Similarity Score (Real): 0.0001 (Fake): 0.0030
# Similarity Score (Real): 0.9430 (Fake): 0.1441
# Similarity Score (Real): 0.0011 (Fake): 0.0256
# Similarity Score (Real): 0.0046 (Fake): 0.0119
# Similarity Score (Real): 0.9082 (Fake): 0.9976
# Similarity Score (Real): 0.2305 (Fake): 0.0009
# Similarity Score (Real): 0.0342 (Fake): 0.0011
# Similarity Score (Real): 0.9044 (Fake): 0.8403
# Similarity Score (Real): 0.0436 (Fake): 0.2095
# Similarity Score (Real): 0.0005 (Fake): 0.0129
# Similarity Score (Real): 0.9340 (Fake): 0.9858
# Similarity Score (Real): 0.0205 (Fake): 0.0023
# Similarity Score (Real): 0.0005 (Fake): 0.0008
# Similarity Score (Real): 0.8290 (Fake): 0.7717
# Similarity Score (Real): 0.0534 (Fake): 0.0126
# Similarity Score (Real): 0.0055 (Fake): 0.0456
# Similarity Score (Real): 0.9701 (Fake): 0.9588
# Similarity Score (Real): 0.0172 (Fake): 0.0561
# Similarity Score (Real): 0.0088 (Fake): 0.0021
# Similarity Score (Real): 0.6545 (Fake): 0.8832
# Similarity Score (Real): 0.0160 (Fake): 0.0221
# Similarity Score (Real): 0.0015 (Fake): 0.0031
# Similarity Score (Real): 0.9053 (Fake): 0.8524
# Similarity Score (Real): 0.0776 (Fake): 0.0961
# Similarity Score (Real): 0.0120 (Fake): 0.2022
# Similarity Score (Real): 0.9766 (Fake): 0.7329
# Similarity Score (Real): 0.0035 (Fake): 0.0959
# Similarity Score (Real): 0.0047 (Fake): 0.0415
# Similarity Score (Real): 0.7753 (Fake): 0.9905
# Similarity Score (Real): 0.0201 (Fake): 0.0004
# Similarity Score (Real): 0.0141 (Fake): 0.0009
# Similarity Score (Real): 0.7709 (Fake): 0.8375
# Similarity Score (Real): 0.0543 (Fake): 0.2522
# Similarity Score (Real): 0.0187 (Fake): 0.0055
# Similarity Score (Real): 0.9963 (Fake): 0.9280
# Similarity Score (Real): 0.0061 (Fake): 0.1014
# Similarity Score (Real): 0.0004 (Fake): 0.0342
# Similarity Score (Real): 0.9312 (Fake): 0.9680
# Similarity Score (Real): 0.0147 (Fake): 0.0147
# Similarity Score (Real): 0.0022 (Fake): 0.0024
# Similarity Score (Real): 0.9054 (Fake): 0.9714
# Similarity Score (Real): 0.0731 (Fake): 0.0623
# Similarity Score (Real): 0.0022 (Fake): 0.0068
# Similarity Score (Real): 0.9870 (Fake): 0.5683
# Similarity Score (Real): 0.0057 (Fake): 0.2844
# Similarity Score (Real): 0.0021 (Fake): 0.2833
# Similarity Score (Real): 0.7431 (Fake): 0.8881
# Similarity Score (Real): 0.0278 (Fake): 0.0667
# Similarity Score (Real): 0.0256 (Fake): 0.0090
# Similarity Score (Real): 0.4289 (Fake): 0.9333
# Similarity Score (Real): 0.0214 (Fake): 0.0421
# Similarity Score (Real): 0.0229 (Fake): 0.0276
# Similarity Score (Real): 0.8911 (Fake): 0.8755
# Similarity Score (Real): 0.1769 (Fake): 0.0592
# Similarity Score (Real): 0.0045 (Fake): 0.0414
# Similarity Score (Real): 0.9452 (Fake): 0.8744
# Similarity Score (Real): 0.1119 (Fake): 0.0092
# Similarity Score (Real): 0.2399 (Fake): 0.0064
# Similarity Score (Real): 0.7268 (Fake): 0.9781
# Similarity Score (Real): 0.2779 (Fake): 0.2012
# Similarity Score (Real): 0.0050 (Fake): 0.0186
# Similarity Score (Real): 0.9826 (Fake): 0.9663
# Similarity Score (Real): 0.2704 (Fake): 0.0709
# Similarity Score (Real): 0.0013 (Fake): 0.0022
# Similarity Score (Real): 0.7884 (Fake): 0.6670
# Similarity Score (Real): 0.0005 (Fake): 0.0032
# Similarity Score (Real): 0.0031 (Fake): 0.0246
# Similarity Score (Real): 0.9902 (Fake): 0.9776
# Similarity Score (Real): 0.5365 (Fake): 0.0239
# Similarity Score (Real): 0.0012 (Fake): 0.0111
# Similarity Score (Real): 0.9955 (Fake): 0.8758
# Similarity Score (Real): 0.0011 (Fake): 0.0374
# Similarity Score (Real): 0.0114 (Fake): 0.0316
# Similarity Score (Real): 0.9199 (Fake): 0.9603
# Similarity Score (Real): 0.0534 (Fake): 0.0875
# Similarity Score (Real): 0.0077 (Fake): 0.0188
# Similarity Score (Real): 0.8102 (Fake): 0.9622
# Similarity Score (Real): 0.0049 (Fake): 0.1105
# Similarity Score (Real): 0.0608 (Fake): 0.1328
# Similarity Score (Real): 0.6001 (Fake): 0.8316
# Similarity Score (Real): 0.1690 (Fake): 0.0368
# Similarity Score (Real): 0.0379 (Fake): 0.0910
# Similarity Score (Real): 0.9823 (Fake): 0.9170
# Similarity Score (Real): 0.0199 (Fake): 0.0295
# Similarity Score (Real): 0.0004 (Fake): 0.0299
# Similarity Score (Real): 0.9375 (Fake): 0.6193
# Similarity Score (Real): 0.0044 (Fake): 0.5394
# Similarity Score (Real): 0.0045 (Fake): 0.1160
# Similarity Score (Real): 0.9792 (Fake): 0.7333
# Similarity Score (Real): 0.0223 (Fake): 0.0383
# Similarity Score (Real): 0.0145 (Fake): 0.0425
# Similarity Score (Real): 0.9115 (Fake): 0.8865
# Similarity Score (Real): 0.0618 (Fake): 0.0573
# Similarity Score (Real): 0.0065 (Fake): 0.0055
# Similarity Score (Real): 0.8866 (Fake): 0.9524
# Similarity Score (Real): 0.0888 (Fake): 0.1667
# Similarity Score (Real): 0.0126 (Fake): 0.0168
# Similarity Score (Real): 0.7885 (Fake): 0.9074
# Similarity Score (Real): 0.0263 (Fake): 0.0299
# Similarity Score (Real): 0.0163 (Fake): 0.0042
# Similarity Score (Real): 0.8962 (Fake): 0.9708
# Similarity Score (Real): 0.0298 (Fake): 0.0316
# Similarity Score (Real): 0.0492 (Fake): 0.0193
# Similarity Score (Real): 0.8675 (Fake): 0.7406
# Similarity Score (Real): 0.0191 (Fake): 0.1799
# Similarity Score (Real): 0.0382 (Fake): 0.0347
# Similarity Score (Real): 0.8650 (Fake): 0.8166
# Similarity Score (Real): 0.0702 (Fake): 0.0174
# Similarity Score (Real): 0.0368 (Fake): 0.0047
# Similarity Score (Real): 0.8763 (Fake): 0.9572
# Similarity Score (Real): 0.0146 (Fake): 0.0412
# Similarity Score (Real): 0.0400 (Fake): 0.0810
# Similarity Score (Real): 0.9863 (Fake): 0.8551
# Similarity Score (Real): 0.0226 (Fake): 0.1845
# Similarity Score (Real): 0.1374 (Fake): 0.1491
# Similarity Score (Real): 0.9852 (Fake): 0.9380
# Similarity Score (Real): 0.0846 (Fake): 0.0105
# Similarity Score (Real): 0.0158 (Fake): 0.0011
# Similarity Score (Real): 0.8554 (Fake): 0.8215
# Similarity Score (Real): 0.0467 (Fake): 0.0107
# Similarity Score (Real): 0.0066 (Fake): 0.1079
# Similarity Score (Real): 0.9906 (Fake): 0.8607
# Similarity Score (Real): 0.0036 (Fake): 0.0729
# Similarity Score (Real): 0.0183 (Fake): 0.1576
# Similarity Score (Real): 0.9683 (Fake): 0.7887
# Similarity Score (Real): 0.0229 (Fake): 0.7205
# Similarity Score (Real): 0.0041 (Fake): 0.0192
# Similarity Score (Real): 0.9322 (Fake): 0.8520
# Similarity Score (Real): 0.0225 (Fake): 0.2547
# Similarity Score (Real): 0.0151 (Fake): 0.0782
# Similarity Score (Real): 0.6905 (Fake): 0.9020
# Similarity Score (Real): 0.0586 (Fake): 0.0179
# Similarity Score (Real): 0.1542 (Fake): 0.0227
# Similarity Score (Real): 0.9123 (Fake): 0.8647
# Similarity Score (Real): 0.0880 (Fake): 0.0940
# Similarity Score (Real): 0.0072 (Fake): 0.0156
# Similarity Score (Real): 0.9938 (Fake): 0.8865
# Similarity Score (Real): 0.0434 (Fake): 0.0904
# Similarity Score (Real): 0.0023 (Fake): 0.0964
# Similarity Score (Real): 0.9087 (Fake): 0.9761
# Similarity Score (Real): 0.1621 (Fake): 0.0540
# Similarity Score (Real): 0.2361 (Fake): 0.0118
# Similarity Score (Real): 0.7376 (Fake): 0.9725
# Similarity Score (Real): 0.3017 (Fake): 0.0781
# Similarity Score (Real): 0.0187 (Fake): 0.0045
# Similarity Score (Real): 0.7141 (Fake): 0.6885
# Similarity Score (Real): 0.2755 (Fake): 0.1711
# Similarity Score (Real): 0.0640 (Fake): 0.0714
# Similarity Score (Real): 0.9246 (Fake): 0.9223
# Similarity Score (Real): 0.0473 (Fake): 0.0134
# Similarity Score (Real): 0.0028 (Fake): 0.0148
# Similarity Score (Real): 0.9368 (Fake): 0.9846
# Similarity Score (Real): 0.0072 (Fake): 0.0156
# Similarity Score (Real): 0.0134 (Fake): 0.0056
# Similarity Score (Real): 0.9960 (Fake): 0.9899
# Similarity Score (Real): 0.0066 (Fake): 0.0015
# Similarity Score (Real): 0.0034 (Fake): 0.0166
# Similarity Score (Real): 0.9929 (Fake): 0.8983
# Similarity Score (Real): 0.0018 (Fake): 0.0380
# Similarity Score (Real): 0.0019 (Fake): 0.0622
# Similarity Score (Real): 0.9749 (Fake): 0.9860
# Similarity Score (Real): 0.1869 (Fake): 0.0147
# Similarity Score (Real): 0.0032 (Fake): 0.0431
# Similarity Score (Real): 0.9504 (Fake): 0.7068
# Similarity Score (Real): 0.0461 (Fake): 0.1592
# Similarity Score (Real): 0.0133 (Fake): 0.0510
# Similarity Score (Real): 0.9896 (Fake): 0.8848
# Similarity Score (Real): 0.0046 (Fake): 0.0112
# Similarity Score (Real): 0.0026 (Fake): 0.0053
# Similarity Score (Real): 0.9285 (Fake): 0.8811
# Similarity Score (Real): 0.1448 (Fake): 0.0179
# Similarity Score (Real): 0.0090 (Fake): 0.0148
# Similarity Score (Real): 0.9387 (Fake): 0.8843
# Similarity Score (Real): 0.0132 (Fake): 0.6396
# Similarity Score (Real): 0.0093 (Fake): 0.0173
# Similarity Score (Real): 0.8742 (Fake): 0.7525
# Similarity Score (Real): 0.1591 (Fake): 0.2224
# Similarity Score (Real): 0.0128 (Fake): 0.0198
# Similarity Score (Real): 0.9577 (Fake): 0.9548
# Similarity Score (Real): 0.1326 (Fake): 0.1211
# Similarity Score (Real): 0.0827 (Fake): 0.0014
# Similarity Score (Real): 0.9845 (Fake): 0.9566
# Similarity Score (Real): 0.0236 (Fake): 0.3350
# Similarity Score (Real): 0.0120 (Fake): 0.0002
# Similarity Score (Real): 0.9435 (Fake): 0.9845
# Similarity Score (Real): 0.0200 (Fake): 0.1378
# Similarity Score (Real): 0.0046 (Fake): 0.0050
# Similarity Score (Real): 0.9586 (Fake): 0.9079
# Similarity Score (Real): 0.0137 (Fake): 0.2843
# Similarity Score (Real): 0.0049 (Fake): 0.0189
# Similarity Score (Real): 0.9982 (Fake): 0.7242
# Similarity Score (Real): 0.0004 (Fake): 0.0634
# Similarity Score (Real): 0.0026 (Fake): 0.0177
# Similarity Score (Real): 0.9781 (Fake): 0.9372
# Similarity Score (Real): 0.0554 (Fake): 0.0673
# Similarity Score (Real): 0.0031 (Fake): 0.0052
# Similarity Score (Real): 0.8824 (Fake): 0.9681
# Similarity Score (Real): 0.0393 (Fake): 0.0069
# Similarity Score (Real): 0.0133 (Fake): 0.0054
# Similarity Score (Real): 0.9208 (Fake): 0.9808
# Similarity Score (Real): 0.1827 (Fake): 0.0139
# Similarity Score (Real): 0.0213 (Fake): 0.0052
# Similarity Score (Real): 0.9164 (Fake): 0.9839
# Similarity Score (Real): 0.0063 (Fake): 0.0013
# Similarity Score (Real): 0.0004 (Fake): 0.0015
# Similarity Score (Real): 0.8351 (Fake): 0.9631
# Similarity Score (Real): 0.2218 (Fake): 0.0752
# Similarity Score (Real): 0.0389 (Fake): 0.0100
# Similarity Score (Real): 0.7760 (Fake): 0.8806
# Similarity Score (Real): 0.1465 (Fake): 0.0042
# Similarity Score (Real): 0.4551 (Fake): 0.0029
# Similarity Score (Real): 0.9548 (Fake): 0.9809
# Similarity Score (Real): 0.0036 (Fake): 0.0512
# Similarity Score (Real): 0.0367 (Fake): 0.0091
# Similarity Score (Real): 0.8954 (Fake): 0.9638
# Similarity Score (Real): 0.0368 (Fake): 0.0258
# Similarity Score (Real): 0.0013 (Fake): 0.0011
# Similarity Score (Real): 0.9656 (Fake): 0.9371
# Similarity Score (Real): 0.0009 (Fake): 0.0024
# Similarity Score (Real): 0.0001 (Fake): 0.0687
# Similarity Score (Real): 0.9854 (Fake): 0.8739
# Similarity Score (Real): 0.0003 (Fake): 0.0238
# Similarity Score (Real): 0.0067 (Fake): 0.0154
# Similarity Score (Real): 0.8913 (Fake): 0.9799
# Similarity Score (Real): 0.0246 (Fake): 0.0166
# Similarity Score (Real): 0.0332 (Fake): 0.0033
# Similarity Score (Real): 0.9388 (Fake): 0.7990
# Similarity Score (Real): 0.0483 (Fake): 0.0920
# Similarity Score (Real): 0.0095 (Fake): 0.0130
# Similarity Score (Real): 0.9792 (Fake): 0.9626
# Similarity Score (Real): 0.0611 (Fake): 0.0065
# Similarity Score (Real): 0.0094 (Fake): 0.0369
# Similarity Score (Real): 0.9230 (Fake): 0.8526
# Similarity Score (Real): 0.0048 (Fake): 0.0361
# Similarity Score (Real): 0.0060 (Fake): 0.0229
# Similarity Score (Real): 0.8265 (Fake): 0.9292
# Similarity Score (Real): 0.2619 (Fake): 0.0643
# Similarity Score (Real): 0.0329 (Fake): 0.0265
# Similarity Score (Real): 0.9571 (Fake): 0.9114
# Similarity Score (Real): 0.0155 (Fake): 0.0734
# Similarity Score (Real): 0.0004 (Fake): 0.0029
# Similarity Score (Real): 0.9465 (Fake): 0.9446
# Similarity Score (Real): 0.2503 (Fake): 0.0817
# Similarity Score (Real): 0.0163 (Fake): 0.0260
# Similarity Score (Real): 0.9584 (Fake): 0.8937
# Similarity Score (Real): 0.0411 (Fake): 0.0344
# Similarity Score (Real): 0.0076 (Fake): 0.0018
# Similarity Score (Real): 0.9100 (Fake): 0.9304
# Similarity Score (Real): 0.0065 (Fake): 0.0096
# Similarity Score (Real): 0.0465 (Fake): 0.0301
# Similarity Score (Real): 0.9115 (Fake): 0.9680
# Similarity Score (Real): 0.0320 (Fake): 0.0106
# Similarity Score (Real): 0.0019 (Fake): 0.0038
# Similarity Score (Real): 0.9583 (Fake): 0.9439
# Similarity Score (Real): 0.0194 (Fake): 0.0243
# Similarity Score (Real): 0.0101 (Fake): 0.0196
# Similarity Score (Real): 0.9586 (Fake): 0.9645
# Similarity Score (Real): 0.1520 (Fake): 0.1038
# Similarity Score (Real): 0.0050 (Fake): 0.0026
# Similarity Score (Real): 0.9940 (Fake): 0.9520
# Similarity Score (Real): 0.0077 (Fake): 0.0137
# Similarity Score (Real): 0.0020 (Fake): 0.0002
# Similarity Score (Real): 0.8696 (Fake): 0.9509
# Similarity Score (Real): 0.0387 (Fake): 0.0272
# Similarity Score (Real): 0.0054 (Fake): 0.0100
# Similarity Score (Real): 0.8945 (Fake): 0.9667
# Similarity Score (Real): 0.0102 (Fake): 0.0028
# Similarity Score (Real): 0.0035 (Fake): 0.0278
# Similarity Score (Real): 0.9742 (Fake): 0.9854
# Similarity Score (Real): 0.0404 (Fake): 0.0344
# Similarity Score (Real): 0.0154 (Fake): 0.0012
# Similarity Score (Real): 0.9741 (Fake): 0.9621
# Similarity Score (Real): 0.0061 (Fake): 0.0096
# Similarity Score (Real): 0.0112 (Fake): 0.0036
# Similarity Score (Real): 0.9984 (Fake): 0.9961
# Similarity Score (Real): 0.0207 (Fake): 0.1071
# Similarity Score (Real): 0.0010 (Fake): 0.0054
# Similarity Score (Real): 0.9609 (Fake): 0.6256
# Similarity Score (Real): 0.0005 (Fake): 0.0453
# Similarity Score (Real): 0.0021 (Fake): 0.0031
# Similarity Score (Real): 0.8591 (Fake): 0.8616
# Similarity Score (Real): 0.0160 (Fake): 0.0197
# Similarity Score (Real): 0.0083 (Fake): 0.0419
# Similarity Score (Real): 0.9904 (Fake): 0.9361
# Similarity Score (Real): 0.0151 (Fake): 0.4277
# Similarity Score (Real): 0.0357 (Fake): 0.0065
# Similarity Score (Real): 0.9248 (Fake): 0.9532
# Similarity Score (Real): 0.1907 (Fake): 0.0633
# Similarity Score (Real): 0.0003 (Fake): 0.0031
# Similarity Score (Real): 0.9451 (Fake): 0.8445
# Similarity Score (Real): 0.0059 (Fake): 0.0198
# Similarity Score (Real): 0.0202 (Fake): 0.0730
# Similarity Score (Real): 0.9831 (Fake): 0.9147
# Similarity Score (Real): 0.0173 (Fake): 0.0202
# Similarity Score (Real): 0.0039 (Fake): 0.0351
# Similarity Score (Real): 0.8714 (Fake): 0.9770
# Similarity Score (Real): 0.0100 (Fake): 0.0230
# Similarity Score (Real): 0.0351 (Fake): 0.0054
# Similarity Score (Real): 0.9797 (Fake): 0.9954
# Similarity Score (Real): 0.0769 (Fake): 0.0044
# Similarity Score (Real): 0.0018 (Fake): 0.0019
# Similarity Score (Real): 0.9608 (Fake): 0.9948
# Similarity Score (Real): 0.0247 (Fake): 0.0039
# Similarity Score (Real): 0.0098 (Fake): 0.0020
# Similarity Score (Real): 0.9786 (Fake): 0.9907
# Similarity Score (Real): 0.0058 (Fake): 0.0121
# Similarity Score (Real): 0.0044 (Fake): 0.0011
# Similarity Score (Real): 0.9590 (Fake): 0.9349
# Similarity Score (Real): 0.1815 (Fake): 0.0279
# Similarity Score (Real): 0.0023 (Fake): 0.0025
# Similarity Score (Real): 0.9631 (Fake): 0.9858
# Similarity Score (Real): 0.0017 (Fake): 0.0466
# Similarity Score (Real): 0.0042 (Fake): 0.0328
# Similarity Score (Real): 0.9463 (Fake): 0.9572
# Similarity Score (Real): 0.0381 (Fake): 0.0207
# Similarity Score (Real): 0.0254 (Fake): 0.3637
# Similarity Score (Real): 0.8120 (Fake): 0.9943
# Similarity Score (Real): 0.0111 (Fake): 0.0001
# Similarity Score (Real): 0.0029 (Fake): 0.0004
# Similarity Score (Real): 0.8279 (Fake): 0.8990
# Similarity Score (Real): 0.0009 (Fake): 0.0000
# Similarity Score (Real): 0.0031 (Fake): 0.0009
# Similarity Score (Real): 0.9855 (Fake): 0.9917
# Similarity Score (Real): 0.0025 (Fake): 0.0492
# Similarity Score (Real): 0.0131 (Fake): 0.0089
# Similarity Score (Real): 0.9099 (Fake): 0.9783
# Similarity Score (Real): 0.0066 (Fake): 0.2580
# Similarity Score (Real): 0.0007 (Fake): 0.0137
# Similarity Score (Real): 0.9974 (Fake): 0.9607
# Similarity Score (Real): 0.0043 (Fake): 0.0146
# Similarity Score (Real): 0.0003 (Fake): 0.0013
# Similarity Score (Real): 0.9981 (Fake): 0.9898
# Similarity Score (Real): 0.0080 (Fake): 0.0046
# Similarity Score (Real): 0.0013 (Fake): 0.0087
# Similarity Score (Real): 0.9934 (Fake): 0.9977
# Similarity Score (Real): 0.0032 (Fake): 0.0013
# Similarity Score (Real): 0.0031 (Fake): 0.0007
# Similarity Score (Real): 0.9650 (Fake): 0.9519
# Similarity Score (Real): 0.0093 (Fake): 0.0143
# Similarity Score (Real): 0.0038 (Fake): 0.0047
# Similarity Score (Real): 0.8831 (Fake): 0.9980
# Similarity Score (Real): 0.0203 (Fake): 0.0006
# Similarity Score (Real): 0.0067 (Fake): 0.0020
# Similarity Score (Real): 0.9901 (Fake): 0.9660
# Similarity Score (Real): 0.0382 (Fake): 0.3574
# Similarity Score (Real): 0.0006 (Fake): 0.0045
# Similarity Score (Real): 0.9685 (Fake): 0.9521
# Similarity Score (Real): 0.0228 (Fake): 0.0632
# Similarity Score (Real): 0.0002 (Fake): 0.0032
# Similarity Score (Real): 0.9596 (Fake): 0.9315
# Similarity Score (Real): 0.0512 (Fake): 0.0014
# Similarity Score (Real): 0.0022 (Fake): 0.0454
# Similarity Score (Real): 0.9398 (Fake): 0.9795
# Similarity Score (Real): 0.0060 (Fake): 0.0002
# Similarity Score (Real): 0.0027 (Fake): 0.0025
# Similarity Score (Real): 0.9880 (Fake): 0.9775
# Similarity Score (Real): 0.2226 (Fake): 0.0501
# Similarity Score (Real): 0.0000 (Fake): 0.0001
# Similarity Score (Real): 0.9981 (Fake): 0.3372
# Similarity Score (Real): 0.0000 (Fake): 0.0013
# Similarity Score (Real): 0.0010 (Fake): 0.0130
# Similarity Score (Real): 0.8840 (Fake): 0.9713
# Similarity Score (Real): 0.0062 (Fake): 0.0020
# Similarity Score (Real): 0.0035 (Fake): 0.0060
# Similarity Score (Real): 0.9946 (Fake): 0.9463
# Similarity Score (Real): 0.0622 (Fake): 0.0044
# Similarity Score (Real): 0.0012 (Fake): 0.0057
# Similarity Score (Real): 0.9739 (Fake): 0.9992
# Similarity Score (Real): 0.1610 (Fake): 0.0074
# Similarity Score (Real): 0.0071 (Fake): 0.0018
# Similarity Score (Real): 0.9405 (Fake): 0.9920
# Similarity Score (Real): 0.1414 (Fake): 0.0119
# Similarity Score (Real): 0.0087 (Fake): 0.0001
# Similarity Score (Real): 0.9992 (Fake): 0.8906
# Similarity Score (Real): 0.0075 (Fake): 0.0200
# Similarity Score (Real): 0.0009 (Fake): 0.0012
# Similarity Score (Real): 0.9510 (Fake): 0.9436
# Similarity Score (Real): 0.0141 (Fake): 0.0465
# Similarity Score (Real): 0.0212 (Fake): 0.0081
# Similarity Score (Real): 0.9997 (Fake): 0.9971
# Similarity Score (Real): 0.0005 (Fake): 0.0062
# Similarity Score (Real): 0.0001 (Fake): 0.0013
# Similarity Score (Real): 0.9652 (Fake): 0.9777
# Similarity Score (Real): 0.0328 (Fake): 0.0179
# Similarity Score (Real): 0.0000 (Fake): 0.0163
# Similarity Score (Real): 0.9296 (Fake): 0.9566
# Similarity Score (Real): 0.6443 (Fake): 0.7298
# Similarity Score (Real): 0.0000 (Fake): 0.0001
# Epoch [1/50] | D Loss: 0.3287 | G Loss: 8.6582
# Similarity Score (Real): 0.2744 (Fake): 0.5670
# Similarity Score (Real): 0.0019 (Fake): 0.0003
# Similarity Score (Real): 0.0186 (Fake): 0.0080
# Similarity Score (Real): 0.9944 (Fake): 0.9741
# Similarity Score (Real): 0.0225 (Fake): 0.0442
# Similarity Score (Real): 0.0002 (Fake): 0.0427
# Similarity Score (Real): 0.9961 (Fake): 0.9981
# Similarity Score (Real): 0.0020 (Fake): 0.0002
# Similarity Score (Real): 0.0002 (Fake): 0.0016
# Similarity Score (Real): 0.9950 (Fake): 0.9952
# Similarity Score (Real): 0.0211 (Fake): 0.0005
# Similarity Score (Real): 0.0101 (Fake): 0.0943
# Similarity Score (Real): 0.9219 (Fake): 0.9855
# Similarity Score (Real): 0.0735 (Fake): 0.0010
# Similarity Score (Real): 0.0169 (Fake): 0.0024
# Similarity Score (Real): 0.7587 (Fake): 0.9483
# Similarity Score (Real): 0.1851 (Fake): 0.0553
# Similarity Score (Real): 0.0345 (Fake): 0.0031
# Similarity Score (Real): 0.9791 (Fake): 0.9887
# Similarity Score (Real): 0.0015 (Fake): 0.0309
# Similarity Score (Real): 0.0166 (Fake): 0.0015
# Similarity Score (Real): 0.9967 (Fake): 0.9893
# Similarity Score (Real): 0.0114 (Fake): 0.0484
# Similarity Score (Real): 0.0118 (Fake): 0.0026
# Similarity Score (Real): 0.9670 (Fake): 0.9983
# Similarity Score (Real): 0.0835 (Fake): 0.0018
# Similarity Score (Real): 0.0090 (Fake): 0.0001
# Similarity Score (Real): 0.9731 (Fake): 0.8238
# Similarity Score (Real): 0.0050 (Fake): 0.0156
# Similarity Score (Real): 0.0129 (Fake): 0.0007
# Similarity Score (Real): 0.9994 (Fake): 0.7247
# Similarity Score (Real): 0.0002 (Fake): 0.0202
# Similarity Score (Real): 0.0016 (Fake): 0.0001
# Similarity Score (Real): 0.8759 (Fake): 0.9828
# Similarity Score (Real): 0.0107 (Fake): 0.4662
# Similarity Score (Real): 0.0030 (Fake): 0.0068
# Similarity Score (Real): 0.9670 (Fake): 0.9228
# Similarity Score (Real): 0.0655 (Fake): 0.0464
# Similarity Score (Real): 0.0078 (Fake): 0.0240
# Similarity Score (Real): 0.9951 (Fake): 0.9603
# Similarity Score (Real): 0.0021 (Fake): 0.0064
# Similarity Score (Real): 0.0123 (Fake): 0.0114
# Similarity Score (Real): 0.9989 (Fake): 0.9886
# Similarity Score (Real): 0.0473 (Fake): 0.5439
# Similarity Score (Real): 0.0001 (Fake): 0.0011
# Similarity Score (Real): 0.8188 (Fake): 0.9565
# Similarity Score (Real): 0.0030 (Fake): 0.0015
# Similarity Score (Real): 0.0003 (Fake): 0.0000
# Similarity Score (Real): 0.8779 (Fake): 0.7573
# Similarity Score (Real): 0.0004 (Fake): 0.0095
# Similarity Score (Real): 0.0015 (Fake): 0.0142
# Similarity Score (Real): 0.9576 (Fake): 0.8693
# Similarity Score (Real): 0.0348 (Fake): 0.5039
# Similarity Score (Real): 0.0155 (Fake): 0.0005
# Similarity Score (Real): 0.9529 (Fake): 0.9903
# Similarity Score (Real): 0.0297 (Fake): 0.0000
# Similarity Score (Real): 0.0038 (Fake): 0.0001
# Similarity Score (Real): 0.8833 (Fake): 0.9061
# Similarity Score (Real): 0.2981 (Fake): 0.1274
# Similarity Score (Real): 0.0065 (Fake): 0.0327
# Similarity Score (Real): 0.9969 (Fake): 0.9142
# Similarity Score (Real): 0.0350 (Fake): 0.2090
# Similarity Score (Real): 0.0008 (Fake): 0.0004
# Similarity Score (Real): 0.8555 (Fake): 0.5890
# Similarity Score (Real): 0.0000 (Fake): 0.0000
# Similarity Score (Real): 0.0003 (Fake): 0.0004
# Similarity Score (Real): 0.9043 (Fake): 0.8229
# Similarity Score (Real): 0.0011 (Fake): 0.0001
# Similarity Score (Real): 0.0895 (Fake): 0.0017
# Similarity Score (Real): 0.9758 (Fake): 0.9947
# Similarity Score (Real): 0.0017 (Fake): 0.0021
# Similarity Score (Real): 0.0020 (Fake): 0.0014
# Similarity Score (Real): 0.9937 (Fake): 0.9892
# Similarity Score (Real): 0.0191 (Fake): 0.0538
# Similarity Score (Real): 0.0054 (Fake): 0.0365
# Similarity Score (Real): 0.9888 (Fake): 0.9913
# Similarity Score (Real): 0.0215 (Fake): 0.0169
# ...
# Similarity Score (Real): 0.9488 (Fake): 0.9950
# Similarity Score (Real): 0.0383 (Fake): 0.0004
# Similarity Score (Real): 0.0008 (Fake): 0.0000
# Similarity Score (Real): 0.9650 (Fake): 0.9772
# Similarity Score (Real): 0.0279 (Fake): 0.0024
# Similarity Score (Real): 0.0048 (Fake): 0.0170
# Similarity Score (Real): 0.9212 (Fake): 0.9419
# Similarity Score (Real): 0.5313 (Fake): 0.0557
# Similarity Score (Real): 0.0149 (Fake): 0.0019
# Similarity Score (Real): 0.9772 (Fake): 0.9353
# Similarity Score (Real): 0.0041 (Fake): 0.0022
# Similarity Score (Real): 0.0004 (Fake): 0.0064
# Similarity Score (Real): 0.9908 (Fake): 0.9784
# Similarity Score (Real): 0.0014 (Fake): 0.0053
# Similarity Score (Real): 0.0028 (Fake): 0.0060
# Similarity Score (Real): 0.9665 (Fake): 0.9848
# Similarity Score (Real): 0.0033 (Fake): 0.0023
# Similarity Score (Real): 0.0010 (Fake): 0.0192
# Similarity Score (Real): 0.9837 (Fake): 0.9845
# Similarity Score (Real): 0.0010 (Fake): 0.0674
# Similarity Score (Real): 0.0012 (Fake): 0.0032
# Similarity Score (Real): 0.9508 (Fake): 0.9554
# Similarity Score (Real): 0.0060 (Fake): 0.0020
# Similarity Score (Real): 0.0012 (Fake): 0.0001
# Similarity Score (Real): 0.9980 (Fake): 0.9803
# Similarity Score (Real): 0.0001 (Fake): 0.0001
# Similarity Score (Real): 0.0000 (Fake): 0.0000
# Similarity Score (Real): 0.9849 (Fake): 0.9897
# Similarity Score (Real): 0.0000 (Fake): 0.0037
# Similarity Score (Real): 0.0087 (Fake): 0.0000
# Similarity Score (Real): 0.9926 (Fake): 0.9783
# Similarity Score (Real): 0.0004 (Fake): 0.0001
# Similarity Score (Real): 0.0061 (Fake): 0.0074
# Similarity Score (Real): 0.9819 (Fake): 0.9651
# Similarity Score (Real): 0.0013 (Fake): 0.0000
# Similarity Score (Real): 0.0000 (Fake): 0.0003
# Similarity Score (Real): 0.9946 (Fake): 0.9821
# Similarity Score (Real): 0.0008 (Fake): 0.2921
# Similarity Score (Real): 0.0040 (Fake): 0.0009
# Similarity Score (Real): 0.9842 (Fake): 0.9894
# Similarity Score (Real): 0.0045 (Fake): 0.0010
# Similarity Score (Real): 0.0010 (Fake): 0.0002
# Similarity Score (Real): 0.9873 (Fake): 0.9767
# Similarity Score (Real): 0.0035 (Fake): 0.0025
# Similarity Score (Real): 0.0002 (Fake): 0.0092
# Similarity Score (Real): 0.9927 (Fake): 0.9778
# Similarity Score (Real): 0.0005 (Fake): 0.0009
# Similarity Score (Real): 0.0023 (Fake): 0.0037
# Similarity Score (Real): 0.9750 (Fake): 0.9844
# Similarity Score (Real): 0.0005 (Fake): 0.0174
# Similarity Score (Real): 0.0061 (Fake): 0.0046
# Similarity Score (Real): 0.9916 (Fake): 0.9918
# Similarity Score (Real): 0.0079 (Fake): 0.0006
# Similarity Score (Real): 0.0062 (Fake): 0.0051
# Similarity Score (Real): 0.9961 (Fake): 0.9688
# Similarity Score (Real): 0.0008 (Fake): 0.0009
# Similarity Score (Real): 0.0001 (Fake): 0.0008
# Similarity Score (Real): 0.9752 (Fake): 0.9632
# Similarity Score (Real): 0.0024 (Fake): 0.3261
# Similarity Score (Real): 0.0418 (Fake): 0.0093
# Similarity Score (Real): 0.9941 (Fake): 0.9508
# Similarity Score (Real): 0.0005 (Fake): 0.0232
# Similarity Score (Real): 0.0000 (Fake): 0.0012
# Similarity Score (Real): 0.9775 (Fake): 0.9929
# Similarity Score (Real): 0.0015 (Fake): 0.0001
# Similarity Score (Real): 0.0001 (Fake): 0.0044
# Similarity Score (Real): 0.9819 (Fake): 0.9920
# Similarity Score (Real): 0.0001 (Fake): 0.0002
# Similarity Score (Real): 0.0000 (Fake): 0.0001
# Similarity Score (Real): 0.9905 (Fake): 0.9987
# Similarity Score (Real): 0.0008 (Fake): 0.0001
# Similarity Score (Real): 0.0008 (Fake): 0.0017
# Similarity Score (Real): 0.9915 (Fake): 0.9903
# Similarity Score (Real): 0.0045 (Fake): 0.0035
# Similarity Score (Real): 0.0018 (Fake): 0.0005
# Similarity Score (Real): 0.9546 (Fake): 0.9947
# Similarity Score (Real): 0.0010 (Fake): 0.0000
# Similarity Score (Real): 0.0021 (Fake): 0.0013
# Similarity Score (Real): 0.9914 (Fake): 0.9919
# Similarity Score (Real): 0.0003 (Fake): 0.0001
# Similarity Score (Real): 0.0117 (Fake): 0.0017
# Similarity Score (Real): 0.9864 (Fake): 0.9964
# Similarity Score (Real): 0.0226 (Fake): 0.0012
# Similarity Score (Real): 0.0048 (Fake): 0.0011
# Similarity Score (Real): 0.9776 (Fake): 0.9842
# Similarity Score (Real): 0.1803 (Fake): 0.0078
# Similarity Score (Real): 0.0079 (Fake): 0.0027
# Similarity Score (Real): 0.9745 (Fake): 0.9860
# Similarity Score (Real): 0.0044 (Fake): 0.0008
# Similarity Score (Real): 0.0014 (Fake): 0.0004
# Similarity Score (Real): 0.9944 (Fake): 0.9668
# Similarity Score (Real): 0.0030 (Fake): 0.0099
# Similarity Score (Real): 0.0116 (Fake): 0.0009
# Similarity Score (Real): 0.9951 (Fake): 0.9756
# Similarity Score (Real): 0.0001 (Fake): 0.0049
# Similarity Score (Real): 0.0037 (Fake): 0.0002
# Similarity Score (Real): 0.9953 (Fake): 0.9923
# Similarity Score (Real): 0.0074 (Fake): 0.0002
# Similarity Score (Real): 0.0017 (Fake): 0.0120
# Similarity Score (Real): 0.9746 (Fake): 0.9945
# Similarity Score (Real): 0.0129 (Fake): 0.0035
# Similarity Score (Real): 0.0014 (Fake): 0.0002
# Similarity Score (Real): 0.9745 (Fake): 0.9838
# Similarity Score (Real): 0.0061 (Fake): 0.0419
# Similarity Score (Real): 0.0016 (Fake): 0.0040
# Similarity Score (Real): 0.9967 (Fake): 0.9343
# Similarity Score (Real): 0.0000 (Fake): 0.0201
# Similarity Score (Real): 0.0000 (Fake): 0.0003
# Similarity Score (Real): 0.9689 (Fake): 0.9839
# Similarity Score (Real): 0.0003 (Fake): 0.0000
# Similarity Score (Real): 0.0086 (Fake): 0.0002
# Similarity Score (Real): 0.9932 (Fake): 0.9862
# Similarity Score (Real): 0.0040 (Fake): 0.0084
# Similarity Score (Real): 0.0079 (Fake): 0.0007
# Similarity Score (Real): 0.9909 (Fake): 0.9958
# Similarity Score (Real): 0.0001 (Fake): 0.0001
# Similarity Score (Real): 0.0006 (Fake): 0.0000
# Similarity Score (Real): 0.9883 (Fake): 0.9773
# Similarity Score (Real): 0.0002 (Fake): 0.0005
# Similarity Score (Real): 0.0013 (Fake): 0.0018
# Similarity Score (Real): 0.9785 (Fake): 0.9783
# Similarity Score (Real): 0.0005 (Fake): 0.0137
# Similarity Score (Real): 0.0022 (Fake): 0.0014
# Similarity Score (Real): 0.9829 (Fake): 0.9884
# Similarity Score (Real): 0.0018 (Fake): 0.0016
# Similarity Score (Real): 0.0008 (Fake): 0.0275
# Similarity Score (Real): 0.9719 (Fake): 0.9918
# Similarity Score (Real): 0.0111 (Fake): 0.0011
# Similarity Score (Real): 0.0079 (Fake): 0.0050
# Similarity Score (Real): 0.9842 (Fake): 0.9879
# Similarity Score (Real): 0.0033 (Fake): 0.0142
# Similarity Score (Real): 0.0021 (Fake): 0.0003
# Similarity Score (Real): 0.9649 (Fake): 0.9646
# Similarity Score (Real): 0.0046 (Fake): 0.0804
# Similarity Score (Real): 0.0001 (Fake): 0.0012
# Similarity Score (Real): 0.9898 (Fake): 0.9942
# Similarity Score (Real): 0.0001 (Fake): 0.0001
# Similarity Score (Real): 0.0006 (Fake): 0.0070
# Similarity Score (Real): 0.9978 (Fake): 0.9833
# Similarity Score (Real): 0.0001 (Fake): 0.0004
# Similarity Score (Real): 0.0000 (Fake): 0.0007
# Similarity Score (Real): 0.9852 (Fake): 0.9776
# Similarity Score (Real): 0.0115 (Fake): 0.0033
# Similarity Score (Real): 0.0033 (Fake): 0.0009
# Similarity Score (Real): 0.9731 (Fake): 0.9809
# Similarity Score (Real): 0.0001 (Fake): 0.0000
# Similarity Score (Real): 0.0000 (Fake): 0.0001
# Similarity Score (Real): 0.9350 (Fake): 0.9494
# Similarity Score (Real): 0.2822 (Fake): 0.0876
# Similarity Score (Real): 0.0011 (Fake): 0.0328
# Similarity Score (Real): 0.9881 (Fake): 0.9276
# Similarity Score (Real): 0.0000 (Fake): 0.0011
# Similarity Score (Real): 0.0000 (Fake): 0.0476
# Similarity Score (Real): 0.9301 (Fake): 0.9856
# Similarity Score (Real): 0.0520 (Fake): 0.2031
# Similarity Score (Real): 0.0002 (Fake): 0.0004
# Similarity Score (Real): 0.8172 (Fake): 0.9641
# Similarity Score (Real): 0.0001 (Fake): 0.0104
# Similarity Score (Real): 0.0037 (Fake): 0.0115
# Similarity Score (Real): 0.9707 (Fake): 0.9796
# Similarity Score (Real): 0.2900 (Fake): 0.0012
# Similarity Score (Real): 0.0026 (Fake): 0.0001
# Similarity Score (Real): 0.9838 (Fake): 0.9835
# Similarity Score (Real): 0.0026 (Fake): 0.0003
# Similarity Score (Real): 0.0061 (Fake): 0.0046
# Similarity Score (Real): 0.9864 (Fake): 0.9858
# Similarity Score (Real): 0.0585 (Fake): 0.0057
# Similarity Score (Real): 0.0199 (Fake): 0.0595
# Similarity Score (Real): 0.9840 (Fake): 0.9941
# Similarity Score (Real): 0.0181 (Fake): 0.0068
# Similarity Score (Real): 0.0000 (Fake): 0.0101
# Similarity Score (Real): 0.9601 (Fake): 0.9680
# Similarity Score (Real): 0.0149 (Fake): 0.0061
# Similarity Score (Real): 0.0010 (Fake): 0.0007
# Similarity Score (Real): 0.9721 (Fake): 0.9300
# Similarity Score (Real): 0.0000 (Fake): 0.0125
# Similarity Score (Real): 0.0002 (Fake): 0.0161
# Similarity Score (Real): 0.9774 (Fake): 0.9909
# Similarity Score (Real): 0.0006 (Fake): 0.0002
# Similarity Score (Real): 0.0138 (Fake): 0.0027
# Similarity Score (Real): 0.9950 (Fake): 0.9838
# Similarity Score (Real): 0.0087 (Fake): 0.0115
# Similarity Score (Real): 0.0003 (Fake): 0.0029
# Similarity Score (Real): 0.9901 (Fake): 0.9966
# Similarity Score (Real): 0.0668 (Fake): 0.0392
# Similarity Score (Real): 0.0015 (Fake): 0.0002
# Similarity Score (Real): 0.9903 (Fake): 0.9843
# Similarity Score (Real): 0.0038 (Fake): 0.0012
# Similarity Score (Real): 0.0004 (Fake): 0.0031
# Similarity Score (Real): 0.8957 (Fake): 0.9900
# Similarity Score (Real): 0.0023 (Fake): 0.0102
# Similarity Score (Real): 0.0266 (Fake): 0.0003
# Similarity Score (Real): 0.9613 (Fake): 0.9880
# Similarity Score (Real): 0.0018 (Fake): 0.0001
# Similarity Score (Real): 0.0010 (Fake): 0.0000
# Similarity Score (Real): 0.9860 (Fake): 0.9673
# Similarity Score (Real): 0.0030 (Fake): 0.0024
# Similarity Score (Real): 0.0000 (Fake): 0.0028
# Similarity Score (Real): 0.9906 (Fake): 0.9898
# Similarity Score (Real): 0.0009 (Fake): 0.0007
# Similarity Score (Real): 0.0002 (Fake): 0.0001
# Similarity Score (Real): 0.9907 (Fake): 0.9908
# Similarity Score (Real): 0.0083 (Fake): 0.0069
# Similarity Score (Real): 0.0034 (Fake): 0.0013
# Similarity Score (Real): 0.9874 (Fake): 0.9867
# Similarity Score (Real): 0.0307 (Fake): 0.0003
# Similarity Score (Real): 0.0053 (Fake): 0.0039
# Similarity Score (Real): 0.9931 (Fake): 0.9902
# Similarity Score (Real): 0.0004 (Fake): 0.0001
# Similarity Score (Real): 0.0012 (Fake): 0.0000
# Similarity Score (Real): 0.9996 (Fake): 0.9943
# Similarity Score (Real): 0.0000 (Fake): 0.0009
# Similarity Score (Real): 0.0001 (Fake): 0.0371
# Similarity Score (Real): 0.9891 (Fake): 0.9863
# Similarity Score (Real): 0.0020 (Fake): 0.0099
# Similarity Score (Real): 0.0002 (Fake): 0.0015
# Similarity Score (Real): 0.9961 (Fake): 0.9946
# Similarity Score (Real): 0.0003 (Fake): 0.0002
# Similarity Score (Real): 0.0012 (Fake): 0.0015
# Similarity Score (Real): 0.9688 (Fake): 0.9832
# Similarity Score (Real): 0.0097 (Fake): 0.0032
# Similarity Score (Real): 0.0043 (Fake): 0.0060
# Similarity Score (Real): 0.9930 (Fake): 0.9920
# Similarity Score (Real): 0.0017 (Fake): 0.0064
# Similarity Score (Real): 0.0000 (Fake): 0.0005
# Similarity Score (Real): 0.9877 (Fake): 0.9869
# Similarity Score (Real): 0.0006 (Fake): 0.0185
# Similarity Score (Real): 0.0000 (Fake): 0.0004
# Similarity Score (Real): 0.9846 (Fake): 0.9892
# Similarity Score (Real): 0.0029 (Fake): 0.0002
# Similarity Score (Real): 0.0020 (Fake): 0.0002
# Similarity Score (Real): 0.9113 (Fake): 0.9940
# Similarity Score (Real): 0.0051 (Fake): 0.0023
# Similarity Score (Real): 0.0001 (Fake): 0.0002
# Similarity Score (Real): 0.9824 (Fake): 0.9697
# Similarity Score (Real): 0.0167 (Fake): 0.0059
# Similarity Score (Real): 0.0015 (Fake): 0.0458
# Similarity Score (Real): 0.9962 (Fake): 0.9908
# Similarity Score (Real): 0.0006 (Fake): 0.0037
# Similarity Score (Real): 0.0012 (Fake): 0.0003
# Similarity Score (Real): 0.9852 (Fake): 0.9776
# Similarity Score (Real): 0.0236 (Fake): 0.0089
# Similarity Score (Real): 0.0126 (Fake): 0.0060
# Similarity Score (Real): 0.9989 (Fake): 0.9983
# Similarity Score (Real): 0.0008 (Fake): 0.0000
# Similarity Score (Real): 0.0005 (Fake): 0.0007
# Similarity Score (Real): 0.9751 (Fake): 0.9929
# Similarity Score (Real): 0.0125 (Fake): 0.0197
# Similarity Score (Real): 0.0008 (Fake): 0.0044
# Similarity Score (Real): 0.9928 (Fake): 0.9963
# Similarity Score (Real): 0.0047 (Fake): 0.0094
# Similarity Score (Real): 0.0005 (Fake): 0.0010
# Similarity Score (Real): 0.9902 (Fake): 0.9649
# Similarity Score (Real): 0.0001 (Fake): 0.0083
# Similarity Score (Real): 0.0017 (Fake): 0.0274
# Similarity Score (Real): 0.9766 (Fake): 0.9868
# Similarity Score (Real): 0.0362 (Fake): 0.0142
# Similarity Score (Real): 0.0013 (Fake): 0.0139
# Similarity Score (Real): 0.9883 (Fake): 0.9780
# Similarity Score (Real): 0.0024 (Fake): 0.0003
# Similarity Score (Real): 0.0052 (Fake): 0.0009
# Similarity Score (Real): 0.9879 (Fake): 0.9821
# Similarity Score (Real): 0.0049 (Fake): 0.1738
# Similarity Score (Real): 0.0017 (Fake): 0.0013
# Similarity Score (Real): 0.9479 (Fake): 0.9731
# Similarity Score (Real): 0.0326 (Fake): 0.0222
# Similarity Score (Real): 0.0002 (Fake): 0.0217
# Similarity Score (Real): 0.9878 (Fake): 0.9915
# Similarity Score (Real): 0.0061 (Fake): 0.0180
# Similarity Score (Real): 0.1930 (Fake): 0.0143
# Similarity Score (Real): 0.9982 (Fake): 0.9873
# Similarity Score (Real): 0.0041 (Fake): 0.0007
# Similarity Score (Real): 0.0038 (Fake): 0.0005
# Similarity Score (Real): 0.9953 (Fake): 0.9865
# Similarity Score (Real): 0.0002 (Fake): 0.0097
# Similarity Score (Real): 0.0001 (Fake): 0.0029
# Similarity Score (Real): 0.9915 (Fake): 0.9806
# Similarity Score (Real): 0.0011 (Fake): 0.0045
# Similarity Score (Real): 0.0022 (Fake): 0.1669
# Similarity Score (Real): 0.9912 (Fake): 0.9931
# Similarity Score (Real): 0.0005 (Fake): 0.0021
# Similarity Score (Real): 0.0006 (Fake): 0.0006
# Similarity Score (Real): 0.9985 (Fake): 0.9959
# Similarity Score (Real): 0.0000 (Fake): 0.0002
# Similarity Score (Real): 0.0001 (Fake): 0.0012
# Similarity Score (Real): 0.9929 (Fake): 0.9659
# Similarity Score (Real): 0.0028 (Fake): 0.0981
# Similarity Score (Real): 0.0025 (Fake): 0.0021
# Similarity Score (Real): 0.9972 (Fake): 0.9979
# Similarity Score (Real): 0.0001 (Fake): 0.0001
# Similarity Score (Real): 0.0013 (Fake): 0.0003
# Similarity Score (Real): 0.9916 (Fake): 0.9818
# Similarity Score (Real): 0.0247 (Fake): 0.0055
# Similarity Score (Real): 0.0305 (Fake): 0.0018
# Similarity Score (Real): 0.9946 (Fake): 0.9927
# Similarity Score (Real): 0.0158 (Fake): 0.0357
# Similarity Score (Real): 0.0012 (Fake): 0.0002
# Similarity Score (Real): 0.9535 (Fake): 0.9838
# Similarity Score (Real): 0.0082 (Fake): 0.0011
# Similarity Score (Real): 0.0002 (Fake): 0.0084
# Similarity Score (Real): 0.9834 (Fake): 0.9973
# Similarity Score (Real): 0.0011 (Fake): 0.0021
# Similarity Score (Real): 0.0095 (Fake): 0.0002
# Similarity Score (Real): 0.9896 (Fake): 0.9987
# Similarity Score (Real): 0.0047 (Fake): 0.0000
# Similarity Score (Real): 0.0021 (Fake): 0.0002
# Similarity Score (Real): 0.9916 (Fake): 0.9977
# Similarity Score (Real): 0.0000 (Fake): 0.0000
# Similarity Score (Real): 0.0002 (Fake): 0.0001
# Similarity Score (Real): 0.9751 (Fake): 0.9938
# Similarity Score (Real): 0.2317 (Fake): 0.0995
# Similarity Score (Real): 0.0003 (Fake): 0.0125
# Similarity Score (Real): 0.9480 (Fake): 0.9872
# Similarity Score (Real): 0.0199 (Fake): 0.0004
# Similarity Score (Real): 0.0007 (Fake): 0.0001
# Similarity Score (Real): 0.9795 (Fake): 0.9840
# Similarity Score (Real): 0.0407 (Fake): 0.0003
# Similarity Score (Real): 0.0105 (Fake): 0.0012
# Similarity Score (Real): 0.9766 (Fake): 0.9853
# Similarity Score (Real): 0.0030 (Fake): 0.0123
# Similarity Score (Real): 0.0001 (Fake): 0.0013
# Similarity Score (Real): 0.9848 (Fake): 0.9983
# Similarity Score (Real): 0.0213 (Fake): 0.0058
# Similarity Score (Real): 0.0262 (Fake): 0.0000
# Similarity Score (Real): 0.9155 (Fake): 0.9736
# Similarity Score (Real): 0.2182 (Fake): 0.0010
# Similarity Score (Real): 0.0043 (Fake): 0.0007
# Similarity Score (Real): 0.9275 (Fake): 0.9269
# Similarity Score (Real): 0.0004 (Fake): 0.0000
# Similarity Score (Real): 0.0617 (Fake): 0.1398
# Similarity Score (Real): 0.9417 (Fake): 0.9921
# Similarity Score (Real): 0.0122 (Fake): 0.1262
# Similarity Score (Real): 0.0001 (Fake): 0.0003
# Similarity Score (Real): 0.9856 (Fake): 0.9812
# Similarity Score (Real): 0.0006 (Fake): 0.0002
# Similarity Score (Real): 0.0100 (Fake): 0.0006
# Similarity Score (Real): 0.9210 (Fake): 0.9788
# Similarity Score (Real): 0.0004 (Fake): 0.0001
# Similarity Score (Real): 0.0044 (Fake): 0.0017
# Epoch [49/50] | D Loss: 0.0687 | G Loss: 4.4462

# %%
#Saving Models

# %%
torch.save(generator, 'generator_model.pth')
torch.save(discriminator, 'discriminator_model.pth')

# %%
import os
import torch
import torch.nn as nn
import numpy as np
from torchvision.utils import save_image
import matplotlib.pyplot as plt  # Importing Matplotlib for plotting

# Create the directory for fake images if it doesn't exist
if not os.path.exists('./Fake_Images'):
    os.makedirs('./Fake_Images')

# Generator network
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(100, 256, 4, 1, 0, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )
    
    def forward(self, x):
        return self.main(x)

# Siamese-like Discriminator network
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True)
        )
        self.fc = nn.Sequential(
            nn.Linear(256*4*4*2, 1),  # 2 because we concatenate two images (real + generated)
            nn.Sigmoid()
        )
    
    def forward(self, img_real, img_generated):
        features_real = self.cnn(img_real).view(img_real.size(0), -1)
        features_generated = self.cnn(img_generated).view(img_generated.size(0), -1)
        combined_features = torch.cat((features_real, features_generated), 1)
        similarity_score = self.fc(combined_features)
        
        return similarity_score

# Initialize networks
generator = Generator()
discriminator = Discriminator()

# Set the loss criterion
criterion = nn.BCELoss()

# Optimizers for Generator and Discriminator
optimizer_G = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Define number of epochs
epochs = 50

# Check if CUDA is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the models to the selected device
generator.to(device)
discriminator.to(device)

# Lists to hold the loss values
d_losses = []
g_losses = []

# Training loop
for epoch in range(epochs):
    for i, (imgs, _) in enumerate(train_loader):
        # Ground truths for real and fake
        real_labels = torch.ones(imgs.size(0), 1).to(device)
        fake_labels = torch.zeros(imgs.size(0), 1).to(device)
        
        # Move real images to device
        imgs = imgs.to(device)

        ### Train Discriminator ###
        noise = torch.randn(imgs.size(0), 100, 1, 1).to(device)
        fake_imgs = generator(noise)
        
        real_score = discriminator(imgs, imgs)  # Similarity score for real
        fake_score = discriminator(imgs, fake_imgs)  # Similarity score for fake
        
        d_loss_real = criterion(real_score, real_labels)
        d_loss_fake = criterion(fake_score, fake_labels)
        
        d_loss = d_loss_real + d_loss_fake
        
        optimizer_D.zero_grad()
        d_loss.backward()
        optimizer_D.step()

        ### Train Generator ###
        noise = torch.randn(imgs.size(0), 100, 1, 1).to(device)
        fake_imgs = generator(noise)
        
        fake_score = discriminator(imgs, fake_imgs)
        
        g_loss = criterion(fake_score, real_labels)
        
        optimizer_G.zero_grad()
        g_loss.backward()
        optimizer_G.step()

        # Save losses for plotting
        d_losses.append(d_loss.item())
        g_losses.append(g_loss.item())

        # Save generated fake images every few epochs
        if (i + 1) % 100 == 0:  # Save every 100 batches
            save_image(fake_imgs.data, f'./Fake_Images/fake_images_epoch_{epoch+1}_batch_{i+1}.png', normalize=True)

    print(f"Epoch [{epoch}/{epochs}] | D Loss: {d_loss.item():.4f} | G Loss: {g_loss.item():.4f}")

# Print last recorded losses
print(f"Final D Loss: {d_losses[-1]:.4f} | Final G Loss: {g_losses[-1]:.4f}")

# Plotting the losses
plt.figure(figsize=(10, 5))
plt.plot(d_losses, label='Discriminator Loss', color='red')
plt.plot(g_losses, label='Generator Loss', color='blue')
plt.title('Losses during Training')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.show()
